# %% [markdown]
# <a href="https://colab.research.google.com/github/JunSeokCheon/kaggle_H-M_data_analysis/blob/master/del_noimage_underwear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 이미지가 없는 데이터와 underwear류 데이터를 삭제하는 데이터 전처리를 수행합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/2nd_project_elice
# Out:
# /content/drive/MyDrive/2nd_project_elice

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
from PIL import Image
import os

# %%
articles = pd.read_csv("articles.csv")
customers = pd.read_csv("customers.csv")
transactions = pd.read_csv("transactions_train.csv")

# %%
print(articles.shape)
print(transactions.shape)
# Out:
# (105542, 25)
# (31788324, 5)

# %%
test_articles = articles.copy()
test_transactions = transactions.copy()

# %%
print(test_articles.shape)
print(test_transactions.shape)
# Out:
# (105542, 25)
# (31788324, 5)

# %%
ls
# Out:
# 'age_id&attribute&article_id.csv'   data_preprocessing.ipynb
#  age_sex_estimation.ipynb           del_young_kid.ipynb
#  articles.csv                       images/
#  category_data_extraction.ipynb     kaggle.json
#  customers.csv                      transactions_train.csv
#  data/                              visualization.ipynb

# %%
## root : dir과 files가 있는 path
# dirs : root 아래에 있는 폴더들
# files : root 아래에 있는 파일들

# for root, dirs, files in os.walk('./images/'):
#   print(root)
#   print(dirs)
#   print(files)

# %% [markdown]
# ### os 모듈을 활용하여 이미지 파일에서 이미지 이름을 추출합니다.
# - "이미지 이름.jpg" 형태인지 확인하고, "654847001 (1)" 같은 중복 데이터를 확인한 후 이미지이름만 리스트에 저장합니다.
# - 이미지 이름에서 맨 앞에 0을 빼면 article_id와 같기 때문에 이미지 이름만 저장합니다.

# %%
images_names = []
for base, dirs, files in tqdm(os.walk('./images/')):
    for _files in files:
      if len(_files.split(".jpg"))==2:
        if len(_files.split(".jpg")[0].split()) == 1: # "654847001 (1)" -> 이런 파일명을 걸러주기 위해(중복 데이터 제거)
          images_names.append(_files.split(".jpg")[0].split())
# Out:
# 0it [00:00, ?it/s]

# %%
len(images_names)
# Out:
# 105100

# %% [markdown]
# - 이미지 이름과 article_id의 데이터프레임을 만듭니다.
# - 원래 articles 데이터에 새로운 데이터 프레임을 merge하면 이미지 이름이 없는 데이터(NaN)가 이미지가 없는 데이터라고 판단할 수 있습니다.

# %%
image_name_df = pd.DataFrame(images_names, columns = ["image_name"])
image_name_df["article_id"] = image_name_df["image_name"].apply(lambda x: int(x[1:]))
image_name_df.head()
# Out:
#    image_name  article_id
# 0  0194242049   194242049
# 1  0198518010   198518010
# 2  0194037001   194037001
# 3  0192460006   192460006
# 4  0194270044   194270044

# %%
image_article_df = test_articles[["article_id"]].merge(image_name_df, on=["article_id"], how="left")
print(image_article_df.shape)
image_article_df.head()
# Out:
# (105542, 2)
#    article_id  image_name
# 0   108775015  0108775015
# 1   108775044  0108775044
# 2   108775051  0108775051
# 3   110065001  0110065001
# 4   110065002  0110065002

# %%
article_no_image_df = image_article_df.loc[image_article_df.image_name.isna()]
print(article_no_image_df.shape)
article_no_image_df.head()
# Out:
# (442, 2)
#      article_id image_name
# 88    174057028        NaN
# 117   179208001        NaN
# 258   212042043        NaN
# 259   212042066        NaN
# 261   212629004        NaN

# %%
test_articles.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                     Solid                  9             Black  ...
# 1                     Solid                 10             White  ...
# 2                    Stripe                 11         Off White  ...
# 3                     Solid                  9             Black  ...
# 4                     Solid                 10             White  ...
#
#    department_name index_code        index_name index_group_no  \
# 0     Jersey Basic          A        Ladieswear              1
# 1     Jersey Basic          A        Ladieswear              1
# 2     Jersey Basic          A        Ladieswear              1
# 3   Clean Lingerie          B  Lingeries/Tights              1
# 4   Clean Lingerie          B  Lingeries/Tights              1
#
#    index_group_name section_no            section_name garment_group_no  \
# 0        Ladieswear         16  Womens Everyday Basics             1002
# 1        Ladieswear         16  Womens Everyday Basics             1002
# 2        Ladieswear         16  Womens Everyday Basics             1002
# 3        Ladieswear         61         Womens Lingerie             1017
# 4        Ladieswear         61         Womens Lingerie             1017
#
#    garment_group_name                                        detail_desc
# 0        Jersey Basic            Jersey top with narrow shoulder straps.
# 1        Jersey Basic            Jersey top with narrow shoulder straps.
# 2        Jersey Basic            Jersey top with narrow shoulder straps.
# 3   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4   Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
#
# [5 rows x 25 columns]

# %% [markdown]
# - product_group_name이 underwear인 데이터의 article_id를 리스트로 만들어서 저장합니다.
# - 이미지가 없는 데이터의 article_id를 리스트로 만들어서 저장합니다.

# %%
article_underwear_del = test_articles[test_articles["product_group_name"] == "Underwear"]['article_id'].tolist()

# %%
no_image_articleid = article_no_image_df['article_id'].tolist()

# %% [markdown]
# - articles.csv에서 이미지가 없는 데이터와 underwear 데이터를 삭제합니다.

# %%
for id in no_image_articleid:
  index1 = test_articles[test_articles['article_id'] == id].index
  test_articles = test_articles.drop(index = index1, axis = 0)

# %%
for id in article_underwear_del:
  index1 = test_articles[test_articles['article_id'] == id].index
  test_articles = test_articles.drop(index = index1, axis = 0)

# %%
# 4~6월 거래내역 데이터만 사용(전체 데이터 2천만개라서 처리에 곤란)
test_transactions["t_dat"] = pd.to_datetime(test_transactions['t_dat'])
test_transactions = test_transactions.loc[test_transactions.t_dat >= pd.to_datetime('2020-04-01')] #
test_transactions = test_transactions.loc[test_transactions.t_dat <= pd.to_datetime('2020-06-01')] #

# %% [markdown]
# - transactions.csv에서 이미지가 없는 데이터와 underwear 데이터를 삭제합니다.
# - customers.csv는 article에 대한 정보가 없기 때문에 제외해도 됩니다.

# %%
for id in no_image_articleid:
  index1 = test_transactions[test_transactions['article_id'] == id].index
  test_transactions = test_transactions.drop(index = index1, axis = 0)

# %%
for id in article_underwear_del:
  index1 = test_transactions[test_transactions['article_id'] == id].index
  test_transactions = test_transactions.drop(index = index1, axis = 0)

# %%
# 이미지 없는 것과 속옷류 데이터 삭제(2020-04 - 2020-06 데이터에서)
# article : 105542 -> 99638
# transaction : 31788324 -> 2491536
print(test_articles.shape)
print(test_transactions.shape)
# Out:
# (99638, 25)
# (2491536, 5)

# %%
test_articles = test_articles.reset_index(drop=True)

# %%
test_articles
# Out:
#        article_id  product_code               prod_name  product_type_no  \
# 0       108775015        108775               Strap top              253
# 1       108775044        108775               Strap top              253
# 2       108775051        108775           Strap top (1)              253
# 3       111565001        111565     20 den 1p Stockings              304
# 4       111565003        111565     20 den 1p Stockings              302
# ...           ...           ...                     ...              ...
# 99633   953450001        953450  5pk regular Placement1              302
# 99634   953763001        953763       SPORT Malaga tank              253
# 99635   956217002        956217         Cartwheel dress              265
# 99636   957375001        957375        CLAIRE HAIR CLAW               72
# 99637   959461001        959461            Lounge dress              265
#
#       product_type_name  product_group_name  graphical_appearance_no  \
# 0              Vest top  Garment Upper body                  1010016
# 1              Vest top  Garment Upper body                  1010016
# 2              Vest top  Garment Upper body                  1010017
# 3      Underwear Tights      Socks & Tights                  1010016
# 4                 Socks      Socks & Tights                  1010016
# ...                 ...                 ...                      ...
# 99633             Socks      Socks & Tights                  1010014
# 99634          Vest top  Garment Upper body                  1010016
# 99635             Dress   Garment Full body                  1010016
# 99636         Hair clip         Accessories                  1010016
# 99637             Dress   Garment Full body                  1010016
#
#       graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                         Solid                  9             Black  ...
# 1                         Solid                 10             White  ...
# 2                        Stripe                 11         Off White  ...
# 3                         Solid                  9             Black  ...
# 4                         Solid                 13             Beige  ...
# ...                         ...                ...               ...  ...
# 99633           Placement print                  9             Black  ...
# 99634                     Solid                  9             Black  ...
# 99635                     Solid                  9             Black  ...
# 99636                     Solid                  9             Black  ...
# 99637                     Solid                 11         Off White  ...
#
#          department_name index_code        index_name index_group_no  \
# 0           Jersey Basic          A        Ladieswear              1
# 1           Jersey Basic          A        Ladieswear              1
# 2           Jersey Basic          A        Ladieswear              1
# 3           Tights basic          B  Lingeries/Tights              1
# 4           Tights basic          B  Lingeries/Tights              1
# ...                  ...        ...               ...            ...
# 99633          Socks Bin          F          Menswear              3
# 99634             Jersey          A        Ladieswear              1
# 99635             Jersey          A        Ladieswear              1
# 99636  Small Accessories          D           Divided              2
# 99637             Jersey          A        Ladieswear              1
#
#        index_group_name section_no                    section_name  \
# 0            Ladieswear         16          Womens Everyday Basics
# 1            Ladieswear         16          Womens Everyday Basics
# 2            Ladieswear         16          Womens Everyday Basics
# 3            Ladieswear         62  Womens Nightwear, Socks & Tigh
# 4            Ladieswear         62  Womens Nightwear, Socks & Tigh
# ...                 ...        ...                             ...
# 99633          Menswear         26                   Men Underwear
# 99634        Ladieswear          2                            H&M+
# 99635        Ladieswear         18                    Womens Trend
# 99636           Divided         52             Divided Accessories
# 99637        Ladieswear         18                    Womens Trend
#
#       garment_group_no  garment_group_name  \
# 0                 1002        Jersey Basic
# 1                 1002        Jersey Basic
# 2                 1002        Jersey Basic
# 3                 1021    Socks and Tights
# 4                 1021    Socks and Tights
# ...                ...                 ...
# 99633             1021    Socks and Tights
# 99634             1005        Jersey Fancy
# 99635             1005        Jersey Fancy
# 99636             1019         Accessories
# 99637             1005        Jersey Fancy
#
#                                              detail_desc
# 0                Jersey top with narrow shoulder straps.
# 1                Jersey top with narrow shoulder straps.
# 2                Jersey top with narrow shoulder straps.
# 3      Semi shiny nylon stockings with a wide, reinfo...
# 4      Semi shiny nylon stockings with a wide, reinfo...
# ...                                                  ...
# 99633  Socks in a fine-knit cotton blend with a small...
# 99634  Loose-fitting sports vest top in ribbed fast-d...
# 99635  Short, A-line dress in jersey with a round nec...
# 99636                           Large plastic hair claw.
# 99637  Calf-length dress in ribbed jersey made from a...
#
# [99638 rows x 25 columns]

# %%
test_transactions = test_transactions.reset_index(drop=True)

# %%
test_transactions
# Out:
#              t_dat                                        customer_id  \
# 0       2020-04-01  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 1       2020-04-01  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...
# 2       2020-04-01  00083cda041544b2fbb0e0d2905ad17da7cf1007526fb4...
# 3       2020-04-01  000eae69313b4fc1824fa7e439f168cc140bf4c3f3a7e9...
# 4       2020-04-01  000eae69313b4fc1824fa7e439f168cc140bf4c3f3a7e9...
# ...            ...                                                ...
# 2491531 2020-06-01  fffb04448b4082028fcf3f205b05f0ee846da598eeca1f...
# 2491532 2020-06-01  fffb04448b4082028fcf3f205b05f0ee846da598eeca1f...
# 2491533 2020-06-01  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
# 2491534 2020-06-01  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
# 2491535 2020-06-01  fffef3b6b73545df065b521e19f64bf6fe93bfd450ab20...
#
#          article_id     price  sales_channel_id
# 0         727808001  0.067780                 2
# 1         727808007  0.067780                 2
# 2         783504004  0.019051                 2
# 3         599580061  0.012034                 2
# 4         844294002  0.019576                 2
# ...             ...       ...               ...
# 2491531   873977001  0.050831                 2
# 2491532   851317001  0.042356                 2
# 2491533   698286007  0.025407                 2
# 2491534   892051002  0.028797                 2
# 2491535   559601019  0.022017                 2
#
# [2491536 rows x 5 columns]

# %%
ls
# Out:
#  age_sex_estimation.ipynb        'image&json_data'/   refine_data/
#  category_data_extraction.ipynb   images/             visualization.ipynb
#  data_preprocessing.ipynb         inital_data/
#  del_young_kid.ipynb              kaggle.json

# %%
test_articles.to_csv('./refine_data/articles.csv')
test_transactions.to_csv('./refine_data/transactions.csv')
