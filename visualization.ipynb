# %% [markdown]
# <a href="https://colab.research.google.com/github/JunSeokCheon/kaggle_H-M_data_analysis/blob/master/visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/2nd_project_elice
# Out:
# /content/drive/MyDrive/2nd_project_elice

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import plotly.graph_objects as go
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS

# %%
articles = pd.read_csv("articles.csv")
customers = pd.read_csv("customers.csv")
transactions = pd.read_csv("transactions_train.csv")

# %% [markdown]
# # Articles 에 해당하는 그래프 (확장 가능)

# %%
pd.options.display.max_columns = None
articles.head()
# Out:
#    article_id  product_code          prod_name  product_type_no  \
# 0   108775015        108775          Strap top              253
# 1   108775044        108775          Strap top              253
# 2   108775051        108775      Strap top (1)              253
# 3   110065001        110065  OP T-shirt (Idro)              306
# 4   110065002        110065  OP T-shirt (Idro)              306
#
#   product_type_name  product_group_name  graphical_appearance_no  \
# 0          Vest top  Garment Upper body                  1010016
# 1          Vest top  Garment Upper body                  1010016
# 2          Vest top  Garment Upper body                  1010017
# 3               Bra           Underwear                  1010016
# 4               Bra           Underwear                  1010016
#
#   graphical_appearance_name  colour_group_code colour_group_name  \
# 0                     Solid                  9             Black
# 1                     Solid                 10             White
# 2                    Stripe                 11         Off White
# 3                     Solid                  9             Black
# 4                     Solid                 10             White
#
#    perceived_colour_value_id perceived_colour_value_name  \
# 0                          4                        Dark
# 1                          3                       Light
# 2                          1                 Dusty Light
# 3                          4                        Dark
# 4                          3                       Light
#
#    perceived_colour_master_id perceived_colour_master_name  department_no  \
# 0                           5                        Black           1676
# 1                           9                        White           1676
# 2                           9                        White           1676
# 3                           5                        Black           1339
# 4                           9                        White           1339
#
#   department_name index_code        index_name  index_group_no  \
# 0    Jersey Basic          A        Ladieswear               1
# 1    Jersey Basic          A        Ladieswear               1
# 2    Jersey Basic          A        Ladieswear               1
# 3  Clean Lingerie          B  Lingeries/Tights               1
# 4  Clean Lingerie          B  Lingeries/Tights               1
#
#   index_group_name  section_no            section_name  garment_group_no  \
# 0       Ladieswear          16  Womens Everyday Basics              1002
# 1       Ladieswear          16  Womens Everyday Basics              1002
# 2       Ladieswear          16  Womens Everyday Basics              1002
# 3       Ladieswear          61         Womens Lingerie              1017
# 4       Ladieswear          61         Womens Lingerie              1017
#
#   garment_group_name                                        detail_desc
# 0       Jersey Basic            Jersey top with narrow shoulder straps.
# 1       Jersey Basic            Jersey top with narrow shoulder straps.
# 2       Jersey Basic            Jersey top with narrow shoulder straps.
# 3  Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...
# 4  Under-, Nightwear  Microfibre T-shirt bra with underwired, moulde...

# %% [markdown]
# # 1. 상품 대분류 분포

# %%
import plotly.express as px
label = articles.index_group_name.unique()
count = articles.index_group_name.value_counts()
fig = px.pie(articles, values=count, names=label,color_discrete_sequence=px.colors.sequential.Purpor)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="554b8344-1dfe-48c4-b21e-28adaf8a45d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("554b8344-1dfe-48c4-b21e-28adaf8a45d1")) {                    Plotly.newPlot(                        "554b8344-1dfe-48c4-b21e-28adaf8a45d1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Ladieswear","Baby/Children","Menswear","Sport","Divided"],"legendgroup":"","name":"","showlegend":true,"values":[39737,34711,15149,12553,3392],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0," ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
label = articles.index_group_name.unique()
count = articles.index_group_name.value_counts()
plt.figure(figsize=(5, 5))
plt.rc('font', family='NanumBarunGothic') 
plt.rcParams["font.size"] = 12
plt.pie(count.sort_values(ascending=False), 
        labels = label, startangle = 90, counterclock=False, autopct="%1.1f%%")
plt.title("제품 대분류", fontsize = 25)
plt.show()

# %% [markdown]
# # 2. 상품 중분류 분포

# %%
name = articles.product_group_name.unique()
sizes = articles.product_group_name.value_counts()
fig = px.bar(articles, y=sizes, x=name, color = name,color_discrete_sequence=px.colors.sequential.Plotly3
            )
fig.update_layout(
    title="제품 중분류",
    xaxis_title="제품 분류",
    yaxis_title="개수"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b95044ea-d13b-4555-9a48-87d9bb6e9b87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b95044ea-d13b-4555-9a48-87d9bb6e9b87")) {                    Plotly.newPlot(                        "b95044ea-d13b-4555-9a48-87d9bb6e9b87",                        [{"alignmentgroup":"True","hovertemplate":"color=Garment Upper body<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Garment Upper body","marker":{"color":"#0508b8","pattern":{"shape":""}},"name":"Garment Upper body","offsetgroup":"Garment Upper body","orientation":"v","showlegend":true,"textposition":"auto","x":["Garment Upper body"],"xaxis":"x","y":[42741],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Underwear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Underwear","marker":{"color":"#1910d8","pattern":{"shape":""}},"name":"Underwear","offsetgroup":"Underwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Underwear"],"xaxis":"x","y":[19812],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Socks & Tights<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Socks & Tights","marker":{"color":"#3c19f0","pattern":{"shape":""}},"name":"Socks & Tights","offsetgroup":"Socks & Tights","orientation":"v","showlegend":true,"textposition":"auto","x":["Socks & Tights"],"xaxis":"x","y":[13292],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Garment Lower body<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Garment Lower body","marker":{"color":"#6b1cfb","pattern":{"shape":""}},"name":"Garment Lower body","offsetgroup":"Garment Lower body","orientation":"v","showlegend":true,"textposition":"auto","x":["Garment Lower body"],"xaxis":"x","y":[11158],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Accessories<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Accessories","marker":{"color":"#981cfd","pattern":{"shape":""}},"name":"Accessories","offsetgroup":"Accessories","orientation":"v","showlegend":true,"textposition":"auto","x":["Accessories"],"xaxis":"x","y":[5490],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Items<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Items","marker":{"color":"#bf1cfd","pattern":{"shape":""}},"name":"Items","offsetgroup":"Items","orientation":"v","showlegend":true,"textposition":"auto","x":["Items"],"xaxis":"x","y":[5283],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nightwear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Nightwear","marker":{"color":"#dd2bfd","pattern":{"shape":""}},"name":"Nightwear","offsetgroup":"Nightwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Nightwear"],"xaxis":"x","y":[3127],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Unknown<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Unknown","marker":{"color":"#f246fe","pattern":{"shape":""}},"name":"Unknown","offsetgroup":"Unknown","orientation":"v","showlegend":true,"textposition":"auto","x":["Unknown"],"xaxis":"x","y":[2442],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Underwear/nightwear<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Underwear/nightwear","marker":{"color":"#fc67fd","pattern":{"shape":""}},"name":"Underwear/nightwear","offsetgroup":"Underwear/nightwear","orientation":"v","showlegend":true,"textposition":"auto","x":["Underwear/nightwear"],"xaxis":"x","y":[1899],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shoes<br>x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"Shoes","marker":{"color":"#fe88fc","pattern":{"shape":""}},"name":"Shoes","offsetgroup":"Shoes","orientation":"v","showle ...

# %% [markdown]
# # 3. 상품 소분류 분포

# %%
pd.options.display.max_rows = None
articles.groupby(["product_group_name", "product_type_name"]).count()['article_id']
# Out:
# product_group_name     product_type_name
# Accessories            Accessories set                 7
#                        Alice band                      6
#                        Baby Bib                        3
#                        Bag                          1280
#                        Beanie                         56
#                        Belt                          458
#                        Bracelet                      180
#                        Braces                          3
#                        Bucket hat                      7
#                        Cap                            13
#                        Cap/peaked                    573
#                        Dog Wear                       20
#                        Earring                      1159
#                        Earrings                       11
#                        Eyeglasses                      2
#                        Felt hat                       10
#                        Giftbox                        15
#                        Gloves                        367
#                        Hair clip                     244
#                        Hair string                   238
#                        Hair ties                      24
#                        Hair/alice band               854
#                        Hairband                        2
#                        Hat/beanie                   1349
#                        Hat/brim                      396
#                        Headband                        1
#                        Necklace                      581
#                        Other accessories            1034
#                        Ring                          240
#                        Scarf                        1013
#                        Soft Toys                      46
#                        Straw hat                       6
#                        Sunglasses                    621
#                        Tie                           141
#                        Umbrella                       26
#                        Wallet                         77
#                        Watch                          73
#                        Waterbottle                    22
# Bags                   Backpack                        6
#                        Bumbag                          1
#                        Cross-body bag                  5
#                        Shoulder bag                    2
#                        Tote bag                        2
#                        Weekend/Gym bag                 9
# Cosmetic               Chem. cosmetics                 3
#                        Fine cosmetics                 46
# Fun                    Toy                             2
# Furniture              Side table                     13
# Garment Full body      Costumes                       90
#                        Dress                       10362
#                        Dungarees                     309
#                        Garment Set                  1320
#                        Jumpsuit/Playsuit            1147
#                        Outdoor overall                64
# Garment Lower body     Leggings/Tights              1878
#                        Outdoor trousers              130
#                        Shorts                       3939
#                        Skirt                        2696
#                        Trousers                    11169
# Garment Upper body     Blazer                       1110
#                        Blouse                       3979
#                        Bodysuit                      913
#                        Cardigan                     1550
#                        Coat                          460
#                        Hoodie                       2356
#                        Jacket                       3940
#                        Outdoor Waistcoat             154
#                        Polo shirt                    449
#                        Shirt                        3405
#                        Sweater                      9302
#                        T-shirt                      7904
#                        Tailored Waistcoat             73
#                        Top                          4155
#                        Vest top                     2991
# Garment and Shoe care  Clothing mist                   1
#                        Sewing kit                      1
#                        Stain remover spray             2
#                        Washing bag                     1
#                        Wood balls                      1
#                        Zipper head                     3
# Interior textile       Blanket                         1
#                        Cushion                         1
#                        Towel                           1
# Items                  Dog wear                        7
#                        Keychain                        1
#                        Mobile case                     4
#                        Umbrella                        3
#                        Wireless earphone case          2
# Nightwear              Night gown                    171
#                        Pyjama bottom                 220
#                        Pyjama jumpsuit/playsuit      388
#                        Pyjama set                   1120
# Shoes                  Ballerinas                    372
#                        Bootie                         31
#                        Boots                        1028
#                        Flat shoe                     165
#                        Flat shoes                     10
#                        Flip flop                     125
#                        Heeled sandals                202
#                        Heels                          22
#                        Moccasins                       4
#                        Other shoe                    395
#                        Pre-walkers                     1
#                        Pumps                         188
#                        Sandals                       757
#                        Slippers                      249
#                        Sneakers                     1621
#                        Wedge                         113
# Socks & Tights         Leg warmers                     7
#                        Socks                        1889
#                        Underwear Tights              546
# Stationery             Marker pen                      5
# Swimwear               Bikini top                    850
#                        Sarong                         66
#                        Swimsuit                      662
#                        Swimwear bottom              1307
#                        Swimwear set                  192
#                        Swimwear top                   50
# Underwear              Bra                          2212
#                        Bra extender                    1
#                        Kids Underwear top             96
#                        Long John                      30
#                        Nipple covers                  19
#                        Robe                          136
#                        Underdress                     20
#                        Underwear body                174
#                        Underwear bottom             2748
#                        Underwear corset                7
#                        Underwear set                  47
# Underwear/nightwear    Sleep Bag                       6
#                        Sleeping sack                  48
# Unknown                Unknown                       121
# Name: article_id, dtype: int64

# %% [markdown]
# # customers 에 해당하는 그래프 (확장 가능)

# %%
customers.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...

# %% [markdown]
# # 1. 나이 분포

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(figsize=(10,5))
ax = sns.histplot(data=customers, x='age', bins=50, color='orange')
ax.set_xlabel('age distribution')
plt.show()

# %% [markdown]
# # 2. 회원/비회원 분포

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(figsize=(10,5))
ax = sns.histplot(data=customers, x='club_member_status', color='orange')
ax.set_xlabel('club member distribution')
plt.show()

# %% [markdown]
# # 3. 광고 메시지를 받는지에 대한 분포

# %%
pie_data = customers[['customer_id', 'fashion_news_frequency']].groupby('fashion_news_frequency').count()

# %%
sns.set_style("darkgrid")
f, ax = plt.subplots(figsize=(10,5))
colors = sns.color_palette('pastel')
ax.pie(pie_data.customer_id, labels=pie_data.index, colors = colors)
ax.set_facecolor('lightgrey')
ax.set_xlabel('fashion news distribution')
plt.show()

# %% [markdown]
# # Transactions 에 해당하는 그래프 (확장 가능)

# %%
transactions.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %% [markdown]
# # 연도별 매출 현황

# %%
df = transactions.merge(articles,on="article_id")

# %%
def create_year(x):
    year = pd.DatetimeIndex(x).year 
    return year

df['year'] = create_year(df['t_dat'])

# %%
def create_month(x):
    month = pd.DatetimeIndex(x).month_name() 
    return month

df['month'] = create_month(df['t_dat'])

# %%
def create_day(x):
    day = pd.DatetimeIndex(x).day_name() 
    return day

df['day'] = create_day(df['t_dat'])

# %%
df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  3681748607f3287d2c3a65e00bb5fb153de30e9becf158...   663713001
# 2  2018-09-20  4ef5967ff17bf474bffebe5b16bd54878e1d4105f7b4ed...   663713001
# 3  2018-09-20  6b7b10d2d47516c82a6f97332478dab748070f09693f09...   663713001
# 4  2018-09-20  8ac137752bbe914aa4ae6ad007a9a0c5b67a1ab2b2d474...   663713001
#
#       price  sales_channel_id  product_code                 prod_name  \
# 0  0.050831                 2        663713  Atlanta Push Body Harlow
# 1  0.049475                 2        663713  Atlanta Push Body Harlow
# 2  0.050831                 2        663713  Atlanta Push Body Harlow
# 3  0.050831                 1        663713  Atlanta Push Body Harlow
# 4  0.050831                 2        663713  Atlanta Push Body Harlow
#
#    product_type_no product_type_name product_group_name  \
# 0              283    Underwear body          Underwear
# 1              283    Underwear body          Underwear
# 2              283    Underwear body          Underwear
# 3              283    Underwear body          Underwear
# 4              283    Underwear body          Underwear
#
#    graphical_appearance_no graphical_appearance_name  colour_group_code  \
# 0                  1010016                     Solid                  9
# 1                  1010016                     Solid                  9
# 2                  1010016                     Solid                  9
# 3                  1010016                     Solid                  9
# 4                  1010016                     Solid                  9
#
#   colour_group_name  perceived_colour_value_id perceived_colour_value_name  \
# 0             Black                          4                        Dark
# 1             Black                          4                        Dark
# 2             Black                          4                        Dark
# 3             Black                          4                        Dark
# 4             Black                          4                        Dark
#
#    perceived_colour_master_id perceived_colour_master_name  department_no  \
# 0                           5                        Black           1338
# 1                           5                        Black           1338
# 2                           5                        Black           1338
# 3                           5                        Black           1338
# 4                           5                        Black           1338
#
#        department_name index_code        index_name  index_group_no  \
# 0  Expressive Lingerie          B  Lingeries/Tights               1
# 1  Expressive Lingerie          B  Lingeries/Tights               1
# 2  Expressive Lingerie          B  Lingeries/Tights               1
# 3  Expressive Lingerie          B  Lingeries/Tights               1
# 4  Expressive Lingerie          B  Lingeries/Tights               1
#
#   index_group_name  section_no     section_name  garment_group_no  \
# 0       Ladieswear          61  Womens Lingerie              1017
# 1       Ladieswear          61  Womens Lingerie              1017
# 2       Ladieswear          61  Womens Lingerie              1017
# 3       Ladieswear          61  Womens Lingerie              1017
# 4       Ladieswear          61  Womens Lingerie              1017
#
#   garment_group_name                                        detail_desc  year  \
# 0  Under-, Nightwear  Lace push-up body with underwired, moulded, pa...  2018
# 1  Under-, Nightwear  Lace push-up body with underwired, moulded, pa...  2018
# 2  Under-, Nightwear  Lace push-up body with underwired, moulded, pa...  2018
# 3  Under-, Nightwear  Lace push-up body with underwired, moulded, pa...  2018
# 4  Under-, Nightwear  Lace push-up body with underwired, moulded, pa...  2018
#
#        month       day
# 0  September  Thursday
# 1  September  Thursday
# 2  September  Thursday
# 3  September  Thursday
# 4  September  Thursday

# %%
data = df.groupby("year")['price'].sum().reset_index()

# %%
data.head()
# Out:
#    year          price
# 0  2018  130873.959305
# 1  2019  455604.877966
# 2  2020  298167.136780

# %%
px.line(data, x="year",y="price")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9c840fb5-faf1-446b-8eea-b80e5f7745f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c840fb5-faf1-446b-8eea-b80e5f7745f4")) {                    Plotly.newPlot(                        "9c840fb5-faf1-446b-8eea-b80e5f7745f4",                        [{"hovertemplate":"year=%{x}<br>price=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2018,2019,2020],"xaxis":"x","y":[130873.95930508453,455604.87796610093,298167.1367796605],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewid ...

# %% [markdown]
# # 응용
# ### 1. 연령대/성별 TOP 5~10 제품 유형 비교 시각화(필수)
# ### 2. Top 10 제품 분포
# ### 3. 계절 별 Top 10 제품 분포
# ### 4. 계절 별 buyer 유형
# ### 5. 계절 별 어떤 카테고리 상품이 잘 팔리는 지
# ### 6. 연령대 별 선호하는 색
# ### 7. 날짜 별 수익 분포
# ### 8. 카테고리 별 평균 가격을 비교하여 비싼 카테고리 종류의 가격 분포
